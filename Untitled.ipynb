# %%
import  pandas as pd
a=[1,7,2]
myvar=pd.Series(a,index=["x","y","z"])
print(myvar)
print(type(myvar))
print(myvar["y"])
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# <class 'pandas.core.series.Series'>
# 7

# %%
a=(1.4,2,3,4)
myvar=pd.Series(a)
print(myvar)
print(type(myvar))
# Out:
# 0    1.4
# 1    2.0
# 2    3.0
# 3    4.0
# dtype: float64
# <class 'pandas.core.series.Series'>

# %%
student_name=["ram","shyam","radha","geeta","seeta"]
marks=[50,60,70,80,90]
x=pd.Series(marks,index=student_name,name='student_result')
print(x)
# Out:
# ram      50
# shyam    60
# radha    70
# geeta    80
# seeta    90
# Name: student_result, dtype: int64

# %%
calories={"day1":400,"day2":380,"day3":430,"day4":390}
myvar=pd.Series(calories)
#myvar=pd.Series(calories,index=["day1","day2"]), only selective data will be printed
print(myvar)
# Out:
# day1    400
# day2    380
# day3    430
# day4    390
# Name: calories burn per day, dtype: int64

# %%
calories={"day1":400,"day2":380,"day3":430,"day4":390}
myvar=pd.Series(calories,name="calories burn per day")
print(myvar)
# Out:
# day1    400
# day2    380
# day3    430
# day4    390
# Name: calories burn per day, dtype: int64

# %%
myvar.size #series ma data ni size
# Out:
# 4

# %%
myvar.dtype
# Out:
# dtype('int64')

# %%
myvar.name
# Out:
# 'calories burn per day'

# %%
print(myvar.index)
# Out:
# Index(['day1', 'day2', 'day3', 'day4'], dtype='object')

# %%
print(myvar.values)
# Out:
# [400 380 430 390]

# %%
myvar.is_unique
# Out:
# True

# %%
print(pd.Series([55,22,33,44,55]).is_unique)
# Out:
# False

# %%
subs=pd.read_csv("subs.csv",squeeze=True)
print(subs)
type(subs)
subs.min()
subs.max()
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64
# 396

# %%
subs.median()
# Out:
# 123.0

# %%
subs.sum()
# Out:
# 49510

# %%
subs[subs>200].size
# Out:
# 59

# %%
movies=pd.read_csv("bollywood.csv",index_col="movie",squeeze=True)
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.head(10)
# Out:
# movie
# Uri: The Surgical Strike                     Vicky Kaushal
# Battalion 609                                  Vicky Ahuja
# The Accidental Prime Minister (film)           Anupam Kher
# Why Cheat India                              Emraan Hashmi
# Evening Shadows                           Mona Ambegaonkar
#                                                ...
# Namaste England                               Arjun Kapoor
# Andhadhun                               Ayushmann Khurrana
# Badhaai Ho                              Ayushmann Khurrana
# 5 Weddings                                   Nargis Fakhri
# Kaashi in Search of Ganga                  Aishwarya Devan
# Name: lead, Length: 150, dtype: object

# %%
movies.tail()
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
movies["Uri: The Surgical Strike"]
# Out:
# 'Vicky Kaushal'

# %%
movies[::2]
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: object

# %%
movies[[0,1,3,6,8]]
# Out:
# movie
# Uri: The Surgical Strike             Vicky Kaushal
# Battalion 609                          Vicky Ahuja
# Why Cheat India                      Emraan Hashmi
# Fraud Saiyaan                         Arshad Warsi
# Manikarnika: The Queen of Jhansi    Kangana Ranaut
# Name: lead, dtype: object

# %%
movies[-5:-1]
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Name: lead, dtype: object

# %%
"Uri: The Surgical Strike" in movies
# Out:
# True

# %%
"shinchan" in movies
# Out:
# False

# %%
"Alia Bhatt" in movies.values
# Out:
# True
